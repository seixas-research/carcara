# %%
from carcara.dataset_manager import DatasetManager

# %%
dataset = DatasetManager(filename="data/noisy_samples.xyz", seed=876)

dataset.train_test_split(train_ratio=0.8)
# Out:
# Total configurations: 100
# Train set: 80 configurations
# Test set: 20 configurations
# Files saved: train_seed_876.xyz, test_seed_876.xyz
# ([Atoms(symbols='Au108', pbc=True, cell=[[11.987692155347816, 0.17246776918949966, -0.04164595366077519], [-0.05560934509746253, 12.272260997000895, -0.09441111380319096], [0.1338991692669168, -0.16957937567227374, 12.264739499495857]], REF_forces=...),
#   Atoms(symbols='Au108', pbc=True, cell=[[12.200086914315353, -0.19065783420119672, -0.19999230419336847], [0.12689941760756976, 12.158631482613277, -0.1714772254203229], [-0.06261755872378065, 0.002541774500314264, 12.022652409948172]], REF_forces=...),
#   Atoms(symbols='Au108', pbc=True, cell=[[12.015263374787173, 0.08740609374399677, -0.11685945437214278], [0.032615205920967415, 12.310206525394168, -0.009167569826960754], [-0.07428595963936206, 0.030218634882817362, 12.019235535722217]], REF_forces=...),
# ...

# %%
from carcara import __version__
from carcara.core.trainer import Trainer
import warnings
warnings.filterwarnings("ignore")
import os

print(f"Carcará version = {__version__}")
# Out:
# /Users/leseixas/miniconda3/envs/carcara/lib/python3.10/site-packages/e3nn/o3/_wigner.py:10: UserWarning: Environment variable TORCH_FORCE_NO_WEIGHTS_ONLY_LOAD detected, since the`weights_only` argument was not explicitly passed to `torch.load`, forcing weights_only=False.
#   _Jd, _W3j_flat, _W3j_indices = torch.load(os.path.join(os.path.dirname(__file__), 'constants.pt'))
# cuequivariance or cuequivariance_torch is not available. Cuequivariance acceleration will be disabled.
# Carcará version = 26.4.31

# %%
trainer = Trainer(name           = "model_test",
                  train_file     = "../data/splits/train_seed_876.xyz",  # 800 configurations of Au bulk, 108 atoms each
                  valid_file     = "../data/splits/valid_seed_876.xyz",  # 100 configurations of Au bulk, 108 atoms each
                  E0s            = {79: 3.800},                       # Reference energy for Au, in eV/atom
                  max_num_epochs = 200,
                  start_swa      = 100,
                  eval_interval  = 5,
                  num_channels   = 16,
                  max_L          = 0)

# %%
trainer.run_train(path="model_16x0/")
# Out:
# 2026-04-10 15:50:29.022 INFO: ===========VERIFYING SETTINGS===========
# 2026-04-10 15:50:29.023 INFO: Stage Two is activated as start_stage_two was defined
# 2026-04-10 15:50:29.023 INFO: MACE version: 0.3.15
# 2026-04-10 15:50:29.024 INFO: Using CPU
# 2026-04-10 15:50:29.087 INFO: ===========LOADING INPUT DATA===========
# 2026-04-10 15:50:29.088 INFO: Using heads: ['Default']
# 2026-04-10 15:50:29.088 INFO: Using the key specifications to parse data:
# 2026-04-10 15:50:29.089 INFO: Default: KeySpecification(info_keys={'energy': 'REF_energy', 'stress': 'REF_stress', 'virials': 'REF_virials', 'dipole': 'dipole', 'head': 'head', 'elec_temp': 'elec_temp', 'total_charge': 'total_charge', 'polarizability': 'polarizability', 'total_spin': 'total_spin'}, arrays_keys={'forces': 'REF_forces', 'charges': 'REF_charges'})
# 2026-04-10 15:50:29.089 INFO: =============    Processing head Default     ===========
# ...

# %%
os.remove("model_test_compiled.model")
os.remove("model_test.model")
os.remove("model_test_stagetwo_compiled.model")
os.remove("model_test_stagetwo.model")
trainer.clean_directories()

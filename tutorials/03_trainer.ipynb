# %%
from carcara import __version__
from carcara.core.trainer import Trainer
import warnings
warnings.filterwarnings("ignore")

print(f"Carcará version = {__version__}")
# Out:
# Carcará version = 26.4.29

# %%
trainer = Trainer(name           = "model_test",
                  train_file     = "data/splits/train_seed_876.xyz",
                  valid_file     = "data/splits/valid_seed_876.xyz",
                  E0s            = {79: 3.800},
                  max_num_epochs = 200,
                  start_swa      = 10,
                  eval_interval  = 5,
                  num_channels   = 16,
                  max_L          = 0)

# %%
trainer.run_train()
# Out:
# 2026-04-10 12:39:04.072 INFO: ===========VERIFYING SETTINGS===========
# 2026-04-10 12:39:04.075 INFO: Stage Two is activated as start_stage_two was defined
# 2026-04-10 12:39:04.077 INFO: MACE version: 0.3.15
# 2026-04-10 12:39:04.078 INFO: Using CPU
# 2026-04-10 12:39:04.154 INFO: ===========LOADING INPUT DATA===========
# 2026-04-10 12:39:04.155 INFO: Using heads: ['Default']
# 2026-04-10 12:39:04.155 INFO: Using the key specifications to parse data:
# 2026-04-10 12:39:04.156 INFO: Default: KeySpecification(info_keys={'energy': 'REF_energy', 'stress': 'REF_stress', 'virials': 'REF_virials', 'dipole': 'dipole', 'head': 'head', 'elec_temp': 'elec_temp', 'total_charge': 'total_charge', 'polarizability': 'polarizability', 'total_spin': 'total_spin'}, arrays_keys={'forces': 'REF_forces', 'charges': 'REF_charges'})
# 2026-04-10 12:39:04.156 INFO: =============    Processing head Default     ===========
# 2026-04-10 12:39:04.292 INFO: Training set 1/1 [energy: 400, stress: 0, virials: 0, dipole components: 0, head: 400, elec_temp: 0, total_charge: 0, polarizability: 0, total_spin: 0, forces: 400, charges: 0]
# 2026-04-10 12:39:04.296 INFO: Total Training set [energy: 400, stress: 0, virials: 0, dipole components: 0, head: 400, elec_temp: 0, total_charge: 0, polarizability: 0, total_spin: 0, forces: 400, charges: 0]
# 2026-04-10 12:39:04.333 INFO: Validation set 1/1 [energy: 100, stress: 0, virials: 0, dipole components: 0, head: 100, elec_temp: 0, total_charge: 0, polarizability: 0, total_spin: 0, forces: 100, charges: 0]
# 2026-04-10 12:39:04.334 INFO: Total Validation set [energy: 100, stress: 0, virials: 0, dipole components: 0, head: 100, elec_temp: 0, total_charge: 0, polarizability: 0, total_spin: 0, forces: 100, charges: 0]
# 2026-04-10 12:39:04.335 INFO: Total number of configurations: train=400, valid=100, tests=[],
# 2026-04-10 12:39:04.339 INFO: Atomic Numbers used: [np.int64(79)]
# 2026-04-10 12:39:04.340 INFO: Isolated Atomic Energies (E0s) not in training file, using command line argument
# 2026-04-10 12:39:04.341 INFO: Atomic Energies used (z: eV) for head Default: {79: 3.8}
# 2026-04-10 12:39:04.341 INFO: Processing datasets for head 'Default'
# 2026-04-10 12:39:04.666 INFO: Combining 1 list datasets for head 'Default'
# 2026-04-10 12:39:04.749 INFO: Combining 1 list datasets for head 'Default_valid'
# 2026-04-10 12:39:04.749 INFO: Combined validation datasets for Default
# 2026-04-10 12:39:04.749 INFO: Head 'Default' training dataset size: 400
# 2026-04-10 12:39:04.750 INFO: Computing average number of neighbors
# 2026-04-10 12:39:04.919 INFO: Average number of neighbors: 30.49944496154785
# 2026-04-10 12:39:04.920 INFO: During training the following quantities will be reported: energy, forces
# 2026-04-10 12:39:04.920 INFO: ===========MODEL DETAILS===========
# 2026-04-10 12:39:04.984 INFO: Building model
# 2026-04-10 12:39:04.985 INFO: Message passing with 16 channels and max_L=0 (16x0e)
# 2026-04-10 12:39:04.986 INFO: 2 layers, each with correlation order: 2 (body order: 3) and spherical harmonics up to: l=3
# 2026-04-10 12:39:04.987 INFO: 8 radial and 5 basis functions
# 2026-04-10 12:39:04.987 INFO: Radial cutoff: 5.0 A (total receptive field for each atom: 10.0 A)
# 2026-04-10 12:39:04.987 INFO: Distance transform for radial basis functions: None
# 2026-04-10 12:39:04.989 INFO: Hidden irreps: 16x0e
# 2026-04-10 12:39:05.781 INFO: ===========OPTIMIZER INFORMATION===========
# 2026-04-10 12:39:05.782 INFO: Using ADAM as parameter optimizer
# 2026-04-10 12:39:05.782 INFO: Batch size: 10
# 2026-04-10 12:39:05.783 INFO: Using Exponential Moving Average with decay: 0.99
# 2026-04-10 12:39:05.783 INFO: Number of gradient updates: 8000
# 2026-04-10 12:39:05.784 INFO: Learning rate: 0.01, weight decay: 5e-07
# 2026-04-10 12:39:05.784 INFO: WeightedEnergyForcesLoss(energy_weight=10.000, forces_weight=1000.000)
# 2026-04-10 12:39:05.785 INFO: === Layer's learning rates ===
# 2026-04-10 12:39:05.785 INFO: Param group 0: lr = 0.01
# 2026-04-10 12:39:05.786 INFO: Param group 1: lr = 0.01
# 2026-04-10 12:39:05.786 INFO: Param group 2: lr = 0.01
# 2026-04-10 12:39:05.787 INFO: Param group 3: lr = 0.01
# 2026-04-10 12:39:05.787 INFO: Param group 4: lr = 0.01
# 2026-04-10 12:39:05.788 INFO: Stage Two (after 10 epochs) with loss function: WeightedEnergyForcesLoss(energy_weight=1000.000, forces_weight=100.000), with energy weight : 1000.0, forces weight : 100.0 and learning rate : 0.001
# 2026-04-10 12:39:05.826 WARNING: Cannot find checkpoint with tag 'model_test_run-999' in './checkpoints'
# 2026-04-10 12:39:05.826 INFO: Using gradient clipping with tolerance=10.000
# 2026-04-10 12:39:05.827 INFO:
# 2026-04-10 12:39:05.827 INFO: ===========TRAINING===========
# 2026-04-10 12:39:05.828 INFO: Started training, reporting errors on validation set
# 2026-04-10 12:39:05.828 INFO: Loss metrics on validation set
# 2026-04-10 12:39:07.454 INFO: Initial: head: Default, loss=777.18786621, RMSE_E_per_atom= 3322.10 meV, RMSE_F= 3928.54 meV / A
# 2026-04-10 12:39:24.942 INFO: Epoch 0: head: Default, loss=37.07022858, RMSE_E_per_atom= 1256.04 meV, RMSE_F=  851.84 meV / A
# 2026-04-10 12:40:44.503 INFO: Epoch 5: head: Default, loss=1.46445405, RMSE_E_per_atom=  566.01 meV, RMSE_F=  161.51 meV / A
# 2026-04-10 12:41:51.889 INFO: Changing loss based on Stage Two Weights
# 2026-04-10 12:42:10.537 INFO: Epoch 10: head: Default, loss=0.95969033, RMSE_E_per_atom=  133.68 meV, RMSE_F=  115.03 meV / A
# 2026-04-10 12:43:40.967 INFO: Epoch 15: head: Default, loss=0.32551089, RMSE_E_per_atom=   65.38 meV, RMSE_F=  149.51 meV / A
# 2026-04-10 12:45:19.397 INFO: Epoch 20: head: Default, loss=0.24542484, RMSE_E_per_atom=   51.24 meV, RMSE_F=  151.09 meV / A
# 2026-04-10 12:46:57.939 INFO: Epoch 25: head: Default, loss=0.14813711, RMSE_E_per_atom=   33.24 meV, RMSE_F=  136.31 meV / A
# 2026-04-10 12:48:35.297 INFO: Epoch 30: head: Default, loss=0.09219232, RMSE_E_per_atom=   19.36 meV, RMSE_F=  121.20 meV / A
# 2026-04-10 12:50:13.235 INFO: Epoch 35: head: Default, loss=0.07382423, RMSE_E_per_atom=   13.72 meV, RMSE_F=  113.50 meV / A
# 2026-04-10 12:51:53.088 INFO: Epoch 40: head: Default, loss=0.06112041, RMSE_E_per_atom=   10.73 meV, RMSE_F=  105.23 meV / A
# 2026-04-10 12:53:35.262 INFO: Epoch 45: head: Default, loss=0.05253422, RMSE_E_per_atom=    8.58 meV, RMSE_F=   98.85 meV / A
# 2026-04-10 12:55:17.329 INFO: Epoch 50: head: Default, loss=0.04794481, RMSE_E_per_atom=    7.66 meV, RMSE_F=   94.88 meV / A
# 2026-04-10 12:56:52.850 INFO: Epoch 55: head: Default, loss=0.04293991, RMSE_E_per_atom=    7.50 meV, RMSE_F=   89.58 meV / A
# 2026-04-10 12:58:28.673 INFO: Epoch 60: head: Default, loss=0.03969097, RMSE_E_per_atom=    6.41 meV, RMSE_F=   86.76 meV / A
# 2026-04-10 13:00:06.155 INFO: Epoch 65: head: Default, loss=0.03526881, RMSE_E_per_atom=    5.91 meV, RMSE_F=   81.88 meV / A
# 2026-04-10 13:01:44.568 INFO: Epoch 70: head: Default, loss=0.03074062, RMSE_E_per_atom=    4.99 meV, RMSE_F=   76.80 meV / A
# 2026-04-10 13:03:22.128 INFO: Epoch 75: head: Default, loss=0.02725106, RMSE_E_per_atom=    4.16 meV, RMSE_F=   72.64 meV / A
# 2026-04-10 13:05:01.616 INFO: Epoch 80: head: Default, loss=0.02379279, RMSE_E_per_atom=    3.74 meV, RMSE_F=   67.96 meV / A
# 2026-04-10 13:06:40.288 INFO: Epoch 85: head: Default, loss=0.02176765, RMSE_E_per_atom=    3.27 meV, RMSE_F=   65.16 meV / A
# 2026-04-10 13:08:15.005 INFO: Epoch 90: head: Default, loss=0.01991344, RMSE_E_per_atom=    3.25 meV, RMSE_F=   62.26 meV / A
# 2026-04-10 13:09:48.615 INFO: Epoch 95: head: Default, loss=0.01882482, RMSE_E_per_atom=    2.97 meV, RMSE_F=   60.64 meV / A
# 2026-04-10 13:11:22.768 INFO: Epoch 100: head: Default, loss=0.01811241, RMSE_E_per_atom=    3.76 meV, RMSE_F=   59.00 meV / A
# 2026-04-10 13:12:55.676 INFO: Epoch 105: head: Default, loss=0.01784655, RMSE_E_per_atom=    3.17 meV, RMSE_F=   58.90 meV / A
# 2026-04-10 13:14:27.836 INFO: Epoch 110: head: Default, loss=0.01724117, RMSE_E_per_atom=    3.11 meV, RMSE_F=   57.89 meV / A
# 2026-04-10 13:16:03.772 INFO: Epoch 115: head: Default, loss=0.01611975, RMSE_E_per_atom=    2.73 meV, RMSE_F=   56.12 meV / A
# 2026-04-10 13:17:44.112 INFO: Epoch 120: head: Default, loss=0.01530737, RMSE_E_per_atom=    2.59 meV, RMSE_F=   54.72 meV / A
# 2026-04-10 13:19:22.744 INFO: Epoch 125: head: Default, loss=0.01487926, RMSE_E_per_atom=    2.41 meV, RMSE_F=   54.02 meV / A
# 2026-04-10 13:21:00.563 INFO: Epoch 130: head: Default, loss=0.01440528, RMSE_E_per_atom=    2.18 meV, RMSE_F=   53.23 meV / A
# 2026-04-10 13:22:38.794 INFO: Epoch 135: head: Default, loss=0.01401734, RMSE_E_per_atom=    2.08 meV, RMSE_F=   52.54 meV / A
# 2026-04-10 13:24:14.816 INFO: Epoch 140: head: Default, loss=0.01303692, RMSE_E_per_atom=    2.48 meV, RMSE_F=   50.46 meV / A
# 2026-04-10 13:25:46.839 INFO: Epoch 145: head: Default, loss=0.01224859, RMSE_E_per_atom=    1.88 meV, RMSE_F=   49.14 meV / A
# 2026-04-10 13:27:20.937 INFO: Epoch 150: head: Default, loss=0.01187688, RMSE_E_per_atom=    2.11 meV, RMSE_F=   48.28 meV / A
# 2026-04-10 13:28:53.261 INFO: Epoch 155: head: Default, loss=0.01167240, RMSE_E_per_atom=    2.14 meV, RMSE_F=   47.84 meV / A
# 2026-04-10 13:30:31.804 INFO: Epoch 160: head: Default, loss=0.01116982, RMSE_E_per_atom=    1.86 meV, RMSE_F=   46.90 meV / A
# 2026-04-10 13:32:07.056 INFO: Epoch 165: head: Default, loss=0.01099133, RMSE_E_per_atom=    1.93 meV, RMSE_F=   46.49 meV / A
# 2026-04-10 13:33:45.045 INFO: Epoch 170: head: Default, loss=0.01059088, RMSE_E_per_atom=    1.76 meV, RMSE_F=   45.69 meV / A
# 2026-04-10 13:35:25.462 INFO: Epoch 175: head: Default, loss=0.01023892, RMSE_E_per_atom=    1.54 meV, RMSE_F=   44.99 meV / A
# 2026-04-10 13:37:05.146 INFO: Epoch 180: head: Default, loss=0.00999520, RMSE_E_per_atom=    1.79 meV, RMSE_F=   44.35 meV / A
# 2026-04-10 13:38:45.607 INFO: Epoch 185: head: Default, loss=0.00962586, RMSE_E_per_atom=    1.75 meV, RMSE_F=   43.53 meV / A
# 2026-04-10 13:40:27.099 INFO: Epoch 190: head: Default, loss=0.00944506, RMSE_E_per_atom=    1.56 meV, RMSE_F=   43.18 meV / A
# 2026-04-10 13:42:10.477 INFO: Epoch 195: head: Default, loss=0.00941832, RMSE_E_per_atom=    1.72 meV, RMSE_F=   43.06 meV / A
# 2026-04-10 13:43:27.674 INFO: Training complete
# 2026-04-10 13:43:27.675 INFO:
# 2026-04-10 13:43:27.675 INFO: ===========RESULTS===========
# 2026-04-10 13:43:27.677 INFO: Loading checkpoint: ./checkpoints/model_test_run-999_epoch-5.pt
# 2026-04-10 13:43:27.686 INFO: Loaded Stage one model from epoch 5 for evaluation
# 2026-04-10 13:43:27.686 INFO: Saving model to checkpoints/model_test_run-999.model
# 2026-04-10 13:43:27.788 INFO: Compiling model, saving metadata to model_test_compiled.model
# 2026-04-10 13:43:28.148 INFO: Computing metrics for training, validation, and test sets
# 2026-04-10 13:43:28.148 INFO: Skipping evaluation for heads: ['pt_head']
# 2026-04-10 13:43:28.149 INFO: Evaluating train_Default ...
# 2026-04-10 13:43:35.701 INFO: Evaluating valid_Default ...
# 2026-04-10 13:43:37.296 INFO: Error-table on TRAIN and VALID:
# +---------------+---------------------+------------------+-------------------+
# |  config_type  | RMSE E / meV / atom | RMSE F / meV / A | relative F RMSE % |
# +---------------+---------------------+------------------+-------------------+
# | train_Default |          562.4      |        162.5     |          4.11     |
# | valid_Default |          566.0      |        161.5     |          4.16     |
# +---------------+---------------------+------------------+-------------------+
# 2026-04-10 13:43:47.494 INFO: Loading checkpoint: ./checkpoints/model_test_run-999_epoch-195_swa.pt
# 2026-04-10 13:43:47.501 INFO: Loaded Stage two model from epoch 195 for evaluation
# 2026-04-10 13:43:47.501 INFO: Saving model to checkpoints/model_test_run-999_stagetwo.model
# 2026-04-10 13:43:47.579 INFO: Compiling model, saving metadata model_test_stagetwo_compiled.model
# 2026-04-10 13:43:47.901 INFO: Computing metrics for training, validation, and test sets
# 2026-04-10 13:43:47.902 INFO: Skipping evaluation for heads: ['pt_head']
# 2026-04-10 13:43:47.902 INFO: Evaluating train_Default ...
# 2026-04-10 13:43:55.068 INFO: Evaluating valid_Default ...
# 2026-04-10 13:43:56.696 INFO: Error-table on TRAIN and VALID:
# +---------------+---------------------+------------------+-------------------+
# |  config_type  | RMSE E / meV / atom | RMSE F / meV / A | relative F RMSE % |
# +---------------+---------------------+------------------+-------------------+
# | train_Default |            1.7      |         34.2     |          0.86     |
# | valid_Default |            1.7      |         43.1     |          1.11     |
# +---------------+---------------------+------------------+-------------------+
# 2026-04-10 13:44:06.954 INFO: Done

# %%
trainer.clean_directories()
# Out:
# Deleted directory logs
# Deleted directory checkpoints
# Deleted directory results
